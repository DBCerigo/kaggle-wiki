# %%
# %load_ext autoreload
# %autoreload 2 
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [16,9]
plt.style.use('ggplot')
import os
import pandas as pd
import numpy as np 
import pickle as pk
import glob
from fbprophet import Prophet
import sys
sys.path.append('../')
import wiki
from wiki import utils 
import multiprocessing as mp
total_proc = None
from tqdm import tqdm
from IPython.display import clear_output

# %% [markdown]
# # Results Analysis
# * ...

# %%
def load_plot(page, plot_y_org=True):
    forecast = pd.read_feather(PROPHET_PATH+VERSION+page+'df.f')
    wiki.newphet.prophet_plot(forecast, plot_y_org=plot_y_org)
    plt.show()

# %%
PROPHET_PATH = '../data/prophet/'
RESULTS_PATH = 'results/'
VERSION = 'v2.5/'
PREV_VERSION = 'v2/'

# %%
pagedf = pd.read_feather(PROPHET_PATH+'pagedf.f')
ds = pd.read_feather(PROPHET_PATH+'ds.f')

# %%
pages = [x.split('/')[-1] for x in glob.glob(PROPHET_PATH+VERSION+'*df.f')]

# %%
df = pd.read_feather(PROPHET_PATH+RESULTS_PATH+VERSION[:-1]+'df.f')
prev_df = pd.read_feather(PROPHET_PATH+RESULTS_PATH+PREV_VERSION[:-1]+'df.f')
page_index = pd.read_feather(PROPHET_PATH+'page_index.f')

# %%
df[VERSION[:-1]+'_val'].mean()
# Out:
# 55.497131263774811

# %%
prev_df[PREV_VERSION[:-1]+'_val'].mean()
# Out:
# 58.81101798102403

# %%
df.head()
# Out:
#   page_index  v2.5_full    v2.5_val
# 0      61780  27.773549   21.464761
# 1      88262  39.201190  100.961816
# 2      38562  21.890778   33.040040
# 3     139999  52.019643   64.424648
# 4      60766  23.400406   83.653439

# %%
df[VERSION[:-1]+'_val'].sort_values().hist(bins=1000)

# %%
df[VERSION[:-1]+'_val'][(df[VERSION[:-1]+'_val'] > 0) & (df[VERSION[:-1]+'_val'] < 200)].mean()
# Out:
# 54.804670450397126

# %%
df[VERSION[:-1]+'_val'][(df[VERSION[:-1]+'_val'] > 0) & (df[VERSION[:-1]+'_val'] < 40)].mean()
# Out:
# 25.823148633481569

# %%
len(df[VERSION[:-1]+'_val'][(df[VERSION[:-1]+'_val'] > 0) & (df[VERSION[:-1]+'_val'] < 40)])
# Out:
# 59189

# %%
len(df[VERSION[:-1]+'_val'][(df[VERSION[:-1]+'_val'] > 0) & (df[VERSION[:-1]+'_val'] < 30)])
# Out:
# 36850

# %%
len(df[VERSION[:-1]+'_val'][(df[VERSION[:-1]+'_val'] > 0) & (df[VERSION[:-1]+'_val'] < 20)])
# Out:
# 16795

# %%
df[VERSION[:-1]+'_val'].value_counts().head(20)
# Out:
# 0.000000      1169
# 200.000000    1087
# 3.333333       238
# 6.666667       137
# 20.000000      122
# 10.000000      112
# 16.666667      108
# 23.333333       99
# 33.333333       90
# 26.666667       88
# 30.000000       87
# 53.333333       85
# 40.000000       85
# 56.666667       79
# 13.333333       79
# 110.000000      75
# 46.666667       74
# 43.333333       73
# 50.000000       73
# 86.666667       71
# Name: v2.5_val, dtype: int64

# %%
for row in df.sort_values(by=VERSION[:-1]+'_val',ascending=False).iloc[:1].iterrows():
    print('page_index', row[1][0])
    print('v1.6_val', row[1][2])
    load_plot(row[1][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-66f290137627> in <module>()
# ----> 1 for row in df.sort_values(by=VERSION[:-1]+'_val',ascending=False).iloc[:1].iterrows():
#       2     print('page_index', row[1][0])
#       3     print('v1.6_val', row[1][2])
#       4     load_plot(row[1][0])
#
# NameError: name 'df' is not defined

# %%
for row in df.sort_values(
    by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
    print('page_index', row[1][0])
    print('v1.6_val', row[1][2])
    load_plot(row[1][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-926437c7491c> in <module>()
# ----> 1 for row in df.sort_values(
#       2     by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
#       3     print('page_index', row[1][0])
#       4     print('v1.6_val', row[1][2])
#       5     load_plot(row[1][0])
#
# NameError: name 'df' is not defined

# %%
for row in df[(df[VERSION[:-1]+'_val'] > 10)].sort_values(
    by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
    print('page_index', row[1][0])
    print('v1.6_val', row[1][2])
    load_plot(row[1][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ab7cfb1a8a63> in <module>()
# ----> 1 for row in df[(df[VERSION[:-1]+'_val'] > 10)].sort_values(
#       2     by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
#       3     print('page_index', row[1][0])
#       4     print('v1.6_val', row[1][2])
#       5     load_plot(row[1][0])
#
# NameError: name 'df' is not defined

# %%
for row in df[(df[VERSION[:-1]+'_val'] > 20)].sort_values(
    by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
    print('page_index', row[1][0])
    print('v1.6_val', row[1][2])
    load_plot(row[1][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8acca10db7d9> in <module>()
# ----> 1 for row in df[(df[VERSION[:-1]+'_val'] > 20)].sort_values(
#       2     by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
#       3     print('page_index', row[1][0])
#       4     print('v1.6_val', row[1][2])
#       5     load_plot(row[1][0])
#
# NameError: name 'df' is not defined

# %%
for row in df[(df[VERSION[:-1]+'_val'] > 30)].sort_values(
    by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
    print('page_index', row[1][0])
    print('v1.6_val', row[1][2])
    load_plot(row[1][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-600751654d82> in <module>()
# ----> 1 for row in df[(df[VERSION[:-1]+'_val'] > 30)].sort_values(
#       2     by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
#       3     print('page_index', row[1][0])
#       4     print('v1.6_val', row[1][2])
#       5     load_plot(row[1][0])
#
# NameError: name 'df' is not defined

# %%
for row in df[(df[VERSION[:-1]+'_val'] > 40)].sort_values(
    by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
    print('page_index', row[1][0])
    print('v1.6_val', row[1][2])
    load_plot(row[1][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a9611cdf2dd2> in <module>()
# ----> 1 for row in df[(df[VERSION[:-1]+'_val'] > 40)].sort_values(
#       2     by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
#       3     print('page_index', row[1][0])
#       4     print('v1.6_val', row[1][2])
#       5     load_plot(row[1][0])
#
# NameError: name 'df' is not defined

# %%
for row in df[(df[VERSION[:-1]+'_val'] > 70)].sort_values(
    by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
    print('page_index', row[1][0])
    print('v1.6_val', row[1][2])
    load_plot(row[1][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3f6cd9070d39> in <module>()
# ----> 1 for row in df[(df[VERSION[:-1]+'_val'] > 70)].sort_values(
#       2     by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
#       3     print('page_index', row[1][0])
#       4     print('v1.6_val', row[1][2])
#       5     load_plot(row[1][0])
#
# NameError: name 'df' is not defined

# %%
for row in df[(df[VERSION[:-1]+'_val'] > 150)].sort_values(
    by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
    print('page_index', row[1][0])
    print('v1.6_val', row[1][2])
    load_plot(row[1][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-aed83c385df0> in <module>()
# ----> 1 for row in df[(df[VERSION[:-1]+'_val'] > 150)].sort_values(
#       2     by=VERSION[:-1]+'_val',ascending=True).iloc[:1].iterrows():
#       3     print('page_index', row[1][0])
#       4     print('v1.6_val', row[1][2])
#       5     load_plot(row[1][0])
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Testing fillna(0) vs no fill on series that has sudden start?

# %% [markdown]
# ## Consistent Low Views E.g.

# %%
15291

# %%
MODEL_VERSION = 'v2/'

# %%
tforecast = pd.read_feather(PROPHET_PATH+VERSION+'15291'+'df.f')
with open(PROPHET_PATH+MODEL_VERSION+'15291'+'m.pk', 'rb') as file:
    tm = pk.load(file)

# %%
tforecast
# Out:
#             ds         t     trend  seasonal_lower  seasonal_upper  \
# 0   2015-07-01  0.000000  1.506973        0.424733        0.424733
# 1   2015-07-02  0.002045  1.507777        0.168968        0.168968
# 2   2015-07-03  0.004090  1.508580        0.222272        0.222272
# 3   2015-07-04  0.006135  1.509384        0.400125        0.400125
# 4   2015-07-05  0.008180  1.510188       -0.069417       -0.069417
# 5   2015-07-06  0.010225  1.510991        0.536627        0.536627
# 6   2015-07-07  0.012270  1.511795       -0.039062       -0.039062
# 7   2015-07-08  0.014315  1.512598        0.067482        0.067482
# 8   2015-07-09  0.016360  1.513402       -0.182718       -0.182718
# 9   2015-07-10  0.018405  1.514206       -0.118873       -0.118873
# 10  2015-07-11  0.020450  1.515009        0.074407        0.074407
# 11  2015-07-12  0.022495  1.515813       -0.375041       -0.375041
# 12  2015-07-13  0.024540  1.516617        0.255417        0.255417
# 13  2015-07-14  0.026585  1.517420       -0.292002       -0.292002
# 14  2015-07-15  0.028630  1.518224       -0.153903       -0.153903
# 15  2015-07-16  0.030675  1.519027       -0.369931       -0.369931
# 25      -0.251703 -0.076405     -0.076405     -0.076405 -0.328108     1
# 26       0.406062 -0.055055     -0.055055     -0.055055  0.351007     2
# 27      -0.119438 -0.035205     -0.035205     -0.035205 -0.154644     1
# 28       0.035027 -0.017608     -0.017608     -0.017608  0.017419     2
# 29      -0.170226 -0.002945     -0.002945     -0.002945 -0.173171     1
# ..            ...       ...           ...           ...       ...   ...
# 520     -0.065058 -0.599445     -0.599445     -0.599445 -0.664504     1
# 521      0.165336 -0.551639     -0.551639     -0.551639 -0.386303     2
# 522     -0.251703 -0.502172     -0.502172     -0.502172 -0.753875     1
# 523      0.406062 -0.451773     -0.451773     -0.451773 -0.045711     2
# 524     -0.119438 -0.401184     -0.401184     -0.401184 -0.520622     1
# 525      0.035027 -0.351148     -0.351148     -0.351148 -0.316121     2
# 526     -0.170226 -0.302395     -0.302395     -0.302395 -0.472621     1
# 527     -0.065058 -0.255630     -0.255630     -0.255630 -0.320688     2
# 528      0.165336 -0.211514     -0.211514     -0.211514 -0.046178     2
# 529     -0.251703 -0.170655     -0.170655     -0.170655 -0.422358     2
# 530      0.406062 -0.133595     -0.133595     -0.133595  0.272467     2
# 531     -0.119438 -0.100797     -0.100797     -0.100797 -0.220235     2
# 532      0.035027 -0.072639     -0.072639     -0.072639 -0.037612     2
# 533     -0.170226 -0.049403     -0.049403     -0.049403 -0.219629     2
# 534     -0.065058 -0.031274     -0.031274     -0.031274 -0.096332     2
# 535      0.165336 -0.018330     -0.018330     -0.018330  0.147007     2
# 536     -0.251703 -0.010547     -0.010547     -0.010547 -0.262250     2
# 537      0.406062 -0.007799     -0.007799     -0.007799  0.398263     2
# 538     -0.119438 -0.009860     -0.009860     -0.009860 -0.129298     2
# 539      0.035027 -0.016408     -0.016408     -0.016408  0.018619     2
# 540     -0.170226 -0.027039     -0.027039     -0.027039 -0.197264     2
# 541     -0.065058 -0.041272     -0.041272     -0.041272 -0.106330     2
# 542      0.165336 -0.058563     -0.058563     -0.058563  0.106773     2
# 543     -0.251703 -0.078318     -0.078318     -0.078318 -0.330021     2
# 544      0.406062 -0.099907     -0.099907     -0.099907  0.306155     2
# 545     -0.119438 -0.122680     -0.122680     -0.122680 -0.242118     2
# 546      0.035027 -0.145982     -0.145982     -0.145982 -0.110955     2
# 547     -0.170226 -0.169170     -0.169170     -0.169170 -0.339395     2
# 548     -0.065058 -0.191627     -0.191627     -0.191627 -0.256685     2
# 549      0.165336 -0.212778     -0.212778     -0.212778 -0.047442     2
#
#      yhat_org     y  train   y_org
# 0    1.931706   0.0    1.0   0.001
# 1    1.676744   0.0    1.0   0.000
# 2    1.730852   1.0    1.0   1.000
# 3    1.909509   0.0    1.0   0.000
# 4    1.440771   1.0    1.0   1.000
# 5    2.047619   1.0    1.0   1.000
# 6    1.472733   1.0    1.0   1.000
# 7    1.580081   2.0    1.0   2.000
# 8    1.330684   0.0    1.0   0.000
# 9    1.395332   2.0    1.0   2.000
# 10   1.589416   1.0    1.0   1.000
# 11   1.140772   1.0    1.0   1.000
# 12   1.772034   5.0    1.0   5.000
# 13   1.225418   1.0    1.0   1.000
# 14   1.364321   1.0    1.0   1.000
# 15   1.149097   4.0    1.0   4.000
# 16   1.249864   5.0    1.0   5.000
# 17   1.481142   3.0    1.0   3.000
# 18   1.069930   1.0    1.0   1.000
# 19   1.738010   1.0    1.0   1.000
# 20   1.226753   1.0    1.0   1.000
# 21   1.398739   1.0    1.0   1.000
# 22   1.213562   0.0    1.0   0.000
# 23   1.340577   0.0    1.0   0.000
# 24   1.593774   3.0    1.0   3.000
# 25   1.199663   1.0    1.0   1.000
# 26   1.879653   2.0    1.0   2.000
# 27   1.374876   3.0    1.0   3.000
# 28   1.547813   3.0    1.0   3.000
# 29   1.358097   2.0    1.0   2.000
# ..        ...   ...    ...     ...
# 520  1.296078   0.0    0.0   0.000
# 521  1.575153   2.0    0.0   2.000
# 522  1.208455   2.0    0.0   2.000
# 523  1.917493   6.0    0.0   6.000
# 524  1.443456   2.0    0.0   2.000
# 525  1.648832   1.0    0.0   1.000
# 526  1.493206   1.0    0.0   1.000
# 527  1.646013   1.0    0.0   1.000
# 528  1.921398   3.0    0.0   3.000
# 529  1.546092   4.0    0.0   4.000
# 530  2.241792   3.0    0.0   3.000
# 531  1.749964   3.0    0.0   3.000
# 532  1.933461  60.0    0.0  60.000
# 533  1.752319   4.0    0.0   4.000
# 534  1.876491   3.0    0.0   3.000
# 535  2.120703   2.0    0.0   2.000
# 536  1.712321   2.0    0.0   2.000
# 537  2.373708   4.0    0.0   4.000
# 538  1.847022   1.0    0.0   1.000
# 539  1.995813   0.0    0.0   0.000
# 540  1.780804   2.0    0.0   2.000
# 541  1.872613   0.0    0.0   0.000
# 542  2.086591   2.0    0.0   2.000
# 543  1.650671   1.0    0.0   1.000
# 544  2.287721   2.0    0.0   2.000
# 545  1.740322   2.0    0.0   2.000
# 546  1.872359   3.0    0.0   3.000
# 547  1.644794   2.0    0.0   2.000
# 548  1.728378   1.0    0.0   1.000
# 549  1.938496   1.0    0.0   1.000
#
# [550 rows x 21 columns]

# %%
wiki.newphet.prophet_plot(tforecast)

# %%
tforecast.trend.plot()

# %%
tm.plot_components(tforecast);

# %%
tm.changepoints
# Out:
# 15    2015-07-16
# 30    2015-07-31
# 45    2015-08-15
# 61    2015-09-01
# 76    2015-09-16
# 91    2015-10-01
# 106   2015-10-16
# 121   2015-10-31
# 136   2015-11-15
# 152   2015-12-01
# 167   2015-12-16
# 182   2015-12-31
# 197   2016-01-16
# 212   2016-01-31
# 227   2016-02-16
# 243   2016-03-03
# 258   2016-03-18
# 273   2016-04-02
# 288   2016-04-20
# 303   2016-05-07
# 318   2016-05-22
# 334   2016-06-08
# 349   2016-06-23
# 364   2016-07-09
# 379   2016-07-24
# Name: ds, dtype: datetime64[ns]
