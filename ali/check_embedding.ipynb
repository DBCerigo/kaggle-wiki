# %%
import sys

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.manifold import TSNE

sys.path.append('../')
from wiki import rnn_meta

# %matplotlib inline

# %%
weights_path = '../data/rnn_v3_lr2_weights.mdl'

# %%
pages = pd.read_csv('../data/train_1.csv').Page.values

# %%
model = rnn_meta.RNN()

# %%
model.load_state_dict(torch.load(weights_path))

# %% [markdown]
# Here you gotta get out the embedding weights

# %%
parameters = [[0,0,1],[1,0,0],[0,1,0]]

# %%
tsne = TSNE(n_components=2, random_state=0)
Y = tsne.fit_transform(parameters)

start=0; end=3
dat = Y[start:end]
plt.figure(figsize=(15,15))
plt.scatter(dat[:, 0], dat[:, 1])
for label, x, y in zip(pages[start:end], dat[:, 0], dat[:, 1]):
    plt.text(x,y,label, color=np.random.rand(3)*0.7,
                 fontsize=14)
plt.show()
